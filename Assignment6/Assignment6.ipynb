# %%
# %pip install diffusers transformers accelerate torch
# Out:
# Requirement already satisfied: diffusers in c:\users\hp\anaconda3\envs\ml\lib\site-packages (0.37.1)
# Requirement already satisfied: transformers in c:\users\hp\anaconda3\envs\ml\lib\site-packages (5.4.0)
# Requirement already satisfied: accelerate in c:\users\hp\anaconda3\envs\ml\lib\site-packages (1.13.0)
# Requirement already satisfied: torch in c:\users\hp\anaconda3\envs\ml\lib\site-packages (2.11.0)
# Requirement already satisfied: importlib-metadata in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from diffusers) (9.0.0)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from diffusers) (3.25.2)
# Requirement already satisfied: httpx<1.0.0 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from diffusers) (0.27.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from diffusers) (1.8.0)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from diffusers) (2.1.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from diffusers) (2026.3.32)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from diffusers) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from diffusers) (0.7.0)
# Requirement already satisfied: Pillow in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from diffusers) (12.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from transformers) (0.24.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: psutil in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: setuptools<82 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from torch) (2026.3.0)
# Requirement already satisfied: anyio in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from httpx<1.0.0->diffusers) (4.6.2)
# Requirement already satisfied: certifi in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from httpx<1.0.0->diffusers) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from httpx<1.0.0->diffusers) (1.0.2)
# Requirement already satisfied: idna in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from httpx<1.0.0->diffusers) (3.7)
# Requirement already satisfied: sniffio in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from httpx<1.0.0->diffusers) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from httpcore==1.*->httpx<1.0.0->diffusers) (0.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (1.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from importlib-metadata->diffusers) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from requests->diffusers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from requests->diffusers) (2.2.3)
# Requirement already satisfied: click>=8.2.1 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from typer->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from typer->transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from rich>=12.3.0->typer->transformers) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\anaconda3\envs\ml\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from diffusers import StableDiffusionPipeline
# Out:
# `CLIPImageProcessor` requires torchvision (not installed); falling back to `CLIPImageProcessorPil` for backward compatibility. Install torchvision to use the default backend, or import `CLIPImageProcessorPil` directly to silence this warning.
# `SiglipImageProcessor` requires torchvision (not installed); falling back to `SiglipImageProcessorPil` for backward compatibility. Install torchvision to use the default backend, or import `SiglipImageProcessorPil` directly to silence this warning.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# Load model
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")

pipe = pipe.to(device)
# Out:
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# c:\Users\hp\anaconda3\envs\ml\Lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\hp\.cache\huggingface\hub\models--runwayml--stable-diffusion-v1-5. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: C:\Users\hp\.cache\huggingface\hub\models--runwayml--stable-diffusion-v1-5\snapshots\451f4fe16113bff5a5d2269ed5ad43b0592e9a14\text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/396 [00:00<?, ?it/s]
# StableDiffusionSafetyChecker LOAD REPORT from: C:\Users\hp\.cache\huggingface\hub\models--runwayml--stable-diffusion-v1-5\snapshots\451f4fe16113bff5a5d2269ed5ad43b0592e9a14\safety_checker
# Key                                               | Status     |  |
# --------------------------------------------------+------------+--+-
# vision_model.vision_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# Text prompt
prompt = "a futuristic city with flying cars at sunset"

# %%
# Generate image
image = pipe(prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# Save output
image.save("generated_city.png")
print("Image generated successfully.")
# Out:
# Image generated successfully.
